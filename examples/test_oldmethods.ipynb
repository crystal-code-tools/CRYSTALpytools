# %% [markdown]
# **It is used only to test the deprecated methods that has not been removed from the code. Not part of tutorial.**
#
# Whether they work or not is a main concern.
#
# # Properties output and plot
#
# Band plot

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_band, plot_electron_band

obj1 = Properties_output().read_cry_band('electronic_structure/band_hTaAs.BAND')
obj2 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_noso.BAND')
obj3 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_P15.BAND')
obj4 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_P25.BAND')

fig = plot_cry_band([obj1, obj2, obj3, obj4], energy_range=[-5, 5],
                    k_labels=['Gamma', 'M', 'K', 'A', 'L', 'H', 'K'],
                    mode='multi', labels=['NOSOC', 'SCDFT', 'P15', 'P25'],
                    color=['b', 'c', 'g', 'r'],
                    linestl=['-','--','dotted','dashdot'])

fig = plot_electron_band([obj1, obj2, obj3, obj4], energy_range=[-5, 5],
                         k_labels=['Gamma', 'M', 'K', 'A', 'L', 'H', 'K'],
                         mode='compare', labels=['NOSOC', 'SCDFT', 'P15', 'P25'])
# Out:
# /tmp/ipykernel_5265/2691132715.py:4: UserWarning: You are calling a deprecated function. Use 'read_electron_band' instead.
#   obj1 = Properties_output().read_cry_band('electronic_structure/band_hTaAs.BAND')
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/crystal_io.py:3038: UserWarning: Properties output file not found: 3D k path not available
#   return self.read_electron_band(band_file)
# /tmp/ipykernel_5265/2691132715.py:5: UserWarning: You are calling a deprecated function. Use 'read_electron_band' instead.
#   obj2 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_noso.BAND')
# /tmp/ipykernel_5265/2691132715.py:6: UserWarning: You are calling a deprecated function. Use 'read_electron_band' instead.
#   obj3 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_P15.BAND')
# /tmp/ipykernel_5265/2691132715.py:7: UserWarning: You are calling a deprecated function. Use 'read_electron_band' instead.
#   obj4 = Properties_output().read_cry_band('electronic_structure/band_hTaAs_P25.BAND')
# /tmp/ipykernel_5265/2691132715.py:9: UserWarning: You are calling a deprecated function. Use 'plot_electron_bands' instead.
#   fig = plot_cry_band([obj1, obj2, obj3, obj4], energy_range=[-5, 5],
# /tmp/ipykernel_5265/2691132715.py:15: UserWarning: You are calling a deprecated function. Use 'plot_electron_bands' instead.
#   fig = plot_electron_band([obj1, obj2, obj3, obj4], energy_range=[-5, 5],

# %% [markdown]
# Density of states

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_doss, plot_electron_dos

obj1 = Properties_output().read_cry_doss('electronic_structure/doss_96.DOSS')
obj2 = Properties_output().read_cry_doss('electronic_structure/doss_cu.DOSS')

fig = plot_cry_doss(obj1, linestl=['-','--','dotted'], fermi='indigo', color='orange',
                    prj=[1,2,3], energy_range=[-5, 5], dos_range=[0, 10])
fig = plot_electron_dos(obj2, energy_range=[-5, 5], dos_range=[-10, 10], fermi='indigo',
                        overlap=True, beta='down', linewidth=1.5,
                        color=['blue', 'orange', 'limegreen', 'purple'],
                        labels=['prj1', 'prj2', 'prj4', 'Tot'], prj=[1,2,4,5])
# Out:
# /tmp/ipykernel_5265/2551822102.py:4: UserWarning: You are calling a deprecated function. Use 'read_electron_dos' instead.
#   obj1 = Properties_output().read_cry_doss('electronic_structure/doss_96.DOSS')
# /tmp/ipykernel_5265/2551822102.py:5: UserWarning: You are calling a deprecated function. Use 'read_electron_dos' instead.
#   obj2 = Properties_output().read_cry_doss('electronic_structure/doss_cu.DOSS')
# /tmp/ipykernel_5265/2551822102.py:7: UserWarning: You are calling a deprecated function. Use 'plot_electron_doss' instead.
#   fig = plot_cry_doss(obj1, linestl=['-','--','dotted'], fermi='indigo', color='orange',
# /tmp/ipykernel_5265/2551822102.py:9: UserWarning: You are calling a deprecated function. Use 'plot_electron_doss' instead.
#   fig = plot_electron_dos(obj2, energy_range=[-5, 5], dos_range=[-10, 10], fermi='indigo',

# %% [markdown]
# Electronic structure

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_es

obj1 = Properties_output().read_cry_band('electronic_structure/es_grapheneDV.f25')
obj2 = Properties_output().read_cry_doss('electronic_structure/es_grapheneDV.f25')

fig = plot_cry_es(obj1, obj2, color_bd='brown', fermi='limegreen',
                  color_doss=['blue', 'red', 'green'], energy_range=[-4,6],
                  linestl_doss=['-', '--', 'dotted'], prj=[1,2,3],
                  labels=['prj1', 'prj2', 'prj3'], dos_range=[0, 20],
                  k_labels=['Gamma', 'M', 'K', 'A', 'L', 'H', 'K'])
# Out:
# /tmp/ipykernel_5680/2013934129.py:4: UserWarning: You are calling a deprecated function. Use 'read_electron_band' instead.
#   obj1 = Properties_output().read_cry_band('electronic_structure/es_grapheneDV.f25')
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/crystal_io.py:3038: UserWarning: Properties output file not found: 3D k path not available
#   return self.read_electron_band(band_file)
# /tmp/ipykernel_5680/2013934129.py:5: UserWarning: You are calling a deprecated function. Use 'read_electron_dos' instead.
#   obj2 = Properties_output().read_cry_doss('electronic_structure/es_grapheneDV.f25')
# /tmp/ipykernel_5680/2013934129.py:7: UserWarning: You are calling a deprecated function. Use 'plot_electron_banddos' instead.
#   fig = plot_cry_es(obj1, obj2, color_bd='brown', fermi='limegreen',

# %% [markdown]
# Charge density

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_dens_ECHG, plot_spin_ECHG

obj = Properties_output().read_cry_ECHG('charge_density/dens_grapheneMV.f25')
fig = plot_dens_ECHG(obj)
fig = plot_spin_ECHG(obj)
# Out:
# /tmp/ipykernel_6014/1412866539.py:4: UserWarning: You are calling a deprecated function. Use 'read_ECHG' instead.
#   obj = Properties_output().read_cry_ECHG('charge_density/dens_grapheneMV.f25')
# /tmp/ipykernel_6014/1412866539.py:5: UserWarning: You are calling a deprecated function. Use 'plot_electron_banddos' instead.
#   fig = plot_dens_ECHG(obj)
# /tmp/ipykernel_6014/1412866539.py:6: UserWarning: You are calling a deprecated function. Use 'plot_electron_banddos' instead.
#   fig = plot_spin_ECHG(obj)

# %% [markdown]
# Density difference

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_dens_ECHG, plot_spin_ECHG

obj = Properties_output().read_cry_ECHG_delta(
    'charge_density/dens_grapheneMV.f25', 'charge_density/dens_grapheneMV_PATO.f25')
fig = plot_dens_ECHG(obj)
# Out:
# /tmp/ipykernel_6071/2073804959.py:4: UserWarning: You are calling a deprecated function. Use 'read_ECHG' instead.
#   obj = Properties_output().read_cry_ECHG_delta(
# /tmp/ipykernel_6071/2073804959.py:6: UserWarning: You are calling a deprecated function. Use 'plot_electron_banddos' instead.
#   fig = plot_dens_ECHG(obj)

# %% [markdown]
# Topond output surfaces

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_contour

obj = Properties_output().read_cry_contour('topond/topo_urea.SURFLAPP')
fig = plot_cry_contour(obj)
# Out:
# /tmp/ipykernel_6071/3287745872.py:4: UserWarning: You are calling a deprecated function. Use 'read_topond' instead.
#   obj = Properties_output().read_cry_contour('topond/topo_urea.SURFLAPP')
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/crystal_io.py:3078: UserWarning: Properties output file not found: Geometry not available
#   return self.read_topond(properties_output)
# /tmp/ipykernel_6071/3287745872.py:5: UserWarning: You are calling a deprecated function. Use 'plot_topond2D' instead.
#   fig = plot_cry_contour(obj)

# %% [markdown]
# Topond output surface difference

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_contour_differences

obj1 = Properties_output().read_cry_contour('topond/topo_urea.SURFRHOO')
obj2 = Properties_output().read_cry_contour('topond/topo_ureaPATO.SURFRHOO')
fig = plot_cry_contour_differences(obj1, obj2)
# Out:
# /tmp/ipykernel_6071/2012147669.py:4: UserWarning: You are calling a deprecated function. Use 'read_topond' instead.
#   obj1 = Properties_output().read_cry_contour('topond/topo_urea.SURFRHOO')
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/crystal_io.py:3078: UserWarning: Properties output file not found: Geometry not available
#   return self.read_topond(properties_output)
# /tmp/ipykernel_6071/2012147669.py:5: UserWarning: You are calling a deprecated function. Use 'read_topond' instead.
#   obj2 = Properties_output().read_cry_contour('topond/topo_ureaPATO.SURFRHOO')
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/crystal_io.py:3078: UserWarning: Properties output file not found: Geometry not available
#   return self.read_topond(properties_output)
# /tmp/ipykernel_6071/2012147669.py:6: UserWarning: You are calling a deprecated function. Use 'plot_topond2D' instead.
#   fig = plot_cry_contour_differences(obj1, obj2)

# %% [markdown]
# Transport properties, Seebeck - $\mu$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_seebeck_potential

obj = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
fig = plot_cry_seebeck_potential(obj)
# Out:
# /tmp/ipykernel_6071/1694119961.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
# /tmp/ipykernel_6071/1694119961.py:5: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_seebeck_potential(obj)
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
#  S_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, Seebeck - $\rho$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_seebeck_carrier

obj = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
fig = plot_cry_seebeck_carrier(obj)
# Out:
# /tmp/ipykernel_6071/3557699888.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
# /tmp/ipykernel_6071/3557699888.py:5: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_seebeck_carrier(obj)
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
#  S_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, Multi Seebeck

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_multiseebeck

obj1 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
obj2 = Properties_output().read_cry_seebeck('transport/trans_TiNiSn_SK.DAT')
fig = plot_cry_multiseebeck(obj1, obj2)
# Out:
# /tmp/ipykernel_6259/572774574.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj1 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
# /tmp/ipykernel_6259/572774574.py:5: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj2 = Properties_output().read_cry_seebeck('transport/trans_TiNiSn_SK.DAT')
# /tmp/ipykernel_6259/572774574.py:6: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_multiseebeck(obj1, obj2)
# Insert the index of temperature you want to plot
# (i.e. if your temperature are [T1, T2, T3] indexes are [0, 1, 2]) 0
# Insert the lower value of chemical potential you want to plot in eV -6
# Inser the higher value of chemical potential you want to plot in eV -3
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
#  S_xx

# %% [markdown]
# Transport properties, $\sigma-\mu$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_sigma_potential

obj = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
fig = plot_cry_sigma_potential(obj)
# Out:
# /tmp/ipykernel_6259/3449264977.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
# /tmp/ipykernel_6259/3449264977.py:5: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_sigma_potential(obj)
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
#  S_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, $\sigma-\rho$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_sigma_carrier

obj = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
fig = plot_cry_sigma_carrier(obj)
# Out:
# /tmp/ipykernel_6259/1695120354.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
# /tmp/ipykernel_6259/1695120354.py:5: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_sigma_carrier(obj)
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
#  S_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, multi $\sigma$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_multisigma

obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
obj2 = Properties_output().read_cry_sigma('transport/trans_TiNiSn_SG.DAT')
fig = plot_cry_multisigma(obj1, obj2)
# Out:
# /tmp/ipykernel_6259/3547555731.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
# /tmp/ipykernel_6259/3547555731.py:5: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj2 = Properties_output().read_cry_sigma('transport/trans_TiNiSn_SG.DAT')
# /tmp/ipykernel_6259/3547555731.py:6: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_multisigma(obj1, obj2)
# Insert the index of temperature you want to plot
# (i.e. if your temperature are [T1, T2, T3] indexes are [0, 1, 2]) 0
# Insert the lower value of chemical potential you want to plot in eV -5.5
# Inser the higher value of chemical potential you want to plot in eV -3.0
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
#  S_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, Power Factor - $\mu$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_powerfactor_potential

obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
obj2 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
fig = plot_cry_powerfactor_potential(obj2, obj1)
# Out:
# /tmp/ipykernel_6259/3108958610.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
# /tmp/ipykernel_6259/3108958610.py:5: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj2 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
# /tmp/ipykernel_6259/3108958610.py:6: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_powerfactor_potential(obj2, obj1)
# Please, choose the direction you want to plot.
# You can choose among PF_xx, PF_xy, PF_xz, PF_yx, PF_yy, PF_yz, PF_yz, PF_zx, PF_zy, PF_zz
#  PF_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, Power Factor - $\rho$

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_powerfactor_carrier

obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
obj2 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
fig = plot_cry_powerfactor_carrier(obj2, obj1)
# Out:
# /tmp/ipykernel_6592/3422032945.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj1 = Properties_output().read_cry_sigma('transport/trans_Bi2Te3_SG.DAT')
# /tmp/ipykernel_6592/3422032945.py:5: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj2 = Properties_output().read_cry_seebeck('transport/trans_Bi2Te3_SK.DAT')
# /tmp/ipykernel_6592/3422032945.py:6: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_powerfactor_carrier(obj2, obj1)
# Please, choose the direction you want to plot.
# You can choose among PF_xx, PF_xy, PF_xz, PF_yx, PF_yy, PF_yz, PF_yz, PF_zx, PF_zy, PF_zz
#  PF_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.

# %% [markdown]
# Transport properties, thermoelectric dimensionless figure of merit (ZT).

# %%
from CRYSTALpytools.crystal_io import Properties_output
from CRYSTALpytools.plot import plot_cry_zt

obj1 = Properties_output().read_cry_sigma('transport/trans_G2S_SG.DAT')
obj2 = Properties_output().read_cry_seebeck('transport/trans_G2S_SK.DAT')
fig = plot_cry_zt(obj2, obj1)
# Out:
# /tmp/ipykernel_6592/442225322.py:4: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj1 = Properties_output().read_cry_sigma('transport/trans_G2S_SG.DAT')
# /tmp/ipykernel_6592/442225322.py:5: UserWarning: You are calling a deprecated function. Use 'read_transport' instead.
#   obj2 = Properties_output().read_cry_seebeck('transport/trans_G2S_SK.DAT')
# /tmp/ipykernel_6592/442225322.py:6: UserWarning: You are calling a deprecated function. Use 'plot_transport_tensor' instead.
#   fig = plot_cry_zt(obj2, obj1)
# /home/huanyu/apps/anaconda3/envs/crystal_py3.9/lib/python3.9/site-packages/CRYSTALpytools/plot.py:3336: UserWarning: The y axis captions will be displayed in Power Factor. The plot is divided by Kappa.
#   warnings.warn("The y axis captions will be displayed in Power Factor. The plot is divided by Kappa.")
# Please insert the value of ktot in WK-1m-1 802
# Please, choose the direction you want to plot.
# You can choose among ZT_xx, ZT_xy, ZT_xz, ZT_yx, ZT_yy, ZT_yz, ZT_yz, ZT_zx, ZT_zy, ZT_zz
#  ZT_xx
# To differentiate transport coefficients due to n-type or p-type conduction (electrons or holes as majority carriers) dashed and solid lines are used, respectively.
