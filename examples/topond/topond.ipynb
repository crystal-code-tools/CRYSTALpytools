# %%
from CRYSTALpytools.topond import Traj, Surf

obj = Traj.from_file('topo_ureaCrys.TRAJGRAD', 'topo_ureaCrys.out')
fig = obj.plot_2D(cpt_size=100, figsize=[8, 8], traj_style=':b', traj_width=1)

# %%
from CRYSTALpytools.topond import Traj, Surf

obj = Traj.from_file('topo_ureaCrys.TRAJMOLG', 'topo_ureaCrys.out')
obj2 = Surf.from_file('topo_ureaCrys.SURFLAPP', 'topo_ureaCrys.out')
fig = obj.plot_2D(figsize=[8, 8], traj_color='tab:gray',
                  overlay_surf=obj2, isovalues=None)
