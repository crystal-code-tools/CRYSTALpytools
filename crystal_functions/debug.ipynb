# %%
#ls

# %%
from file_readwrite import *
from plot import *

# %%
seebeck= Properties_output().read_cry_sigma('./transport_zrnins_inter_SIGMA.DAT')

# %%
seebeck2= Properties_output().read_cry_sigma('./transport_zrnins_sb_SIGMA.DAT')

# %%
seebeck3= Properties_output().read_cry_sigma('./transport_zrnins_antisito_SIGMA.DAT')

# %%
seebeck4= Properties_output().read_cry_sigma('./boltz_final_newk60_SIGMA.DAT')

# %%
plot_cry_multisigma(seebeck, seebeck2, seebeck3, seebeck4)
# Out:
# Insert the index of temperature you want to plot1
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx

# %%
plot_cry_sigma_potential(seebeck)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx
