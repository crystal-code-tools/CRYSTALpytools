# %%
#ls

# %%
from file_readwrite import *
from plot import *

# %%
seebeck= Properties_output().read_cry_seebeck('./transport_zrnins_inter_SEEBECK.DAT')

# %%
seebeck1= Properties_output().read_cry_seebeck('./boltz_final_newk60_SEEBECK.DAT')

# %%
seebeck2= Properties_output().read_cry_seebeck('./transport_zrnins_antisito_SEEBECK.DAT')

# %%
seebeck3= Properties_output().read_cry_seebeck('./transport_zrnins_sb_SEEBECK.DAT')

# %%
plot_cry_multiseebeck(seebeck, seebeck1, seebeck2, seebeck3)
# Out:
# Insert the index of temperature you want to plot0
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx

# %%
plot_cry_seebeck_potential(seebeck1)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, Syx, S_yy, S_yz, S_yz, S_zx, Szy, S_zz
# szz

# %%
sigma= Properties_output().read_cry_seebeck('./transport_zrnins_antisito_SIGMA.DAT')

# %%
plot_cry_powerfactor(seebeck, sigma)
# Out:
# Please, choose the direction you want to plot.
# You can choose among PF_xx, PF_xy, PF_xz, PF_yx, PF_yy, PF_yz, PF_yz, PF_zx, PF_zy, PF_zz
# pfxx
