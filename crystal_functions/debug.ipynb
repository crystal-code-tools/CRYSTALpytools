# %%
#ls

# %%
from file_readwrite import *
from plot import *

# %%
sigma= Properties_output().read_cry_seebeck('./transport_zrnins_antisito_SIGMA.DAT')

# %%
sigma1 = Properties_output().read_cry_seebeck('./transport_zrnins_sb_SIGMA.DAT')

# %%
sigma2 = Properties_output().read_cry_seebeck('./bi2te3_SIGMA.DAT')

# %%
sigma3 = Properties_output().read_cry_seebeck('./transport_zrnins_inter_SIGMA.DAT')

# %%
plot_cry_multisigma(sigma2, sigma3)
# Out:
# Insert the index of temperature you want to plot
# (i.e. if your temperature are [T1, T2, T3] indexes are [0, 1, 2])0
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx
# 0
# [-5.5  -5.49 -5.48 -5.47 -5.46 -5.45 -5.44 -5.43 -5.42 -5.41 -5.4  -5.39
#  -5.38 -5.37 -5.36 -5.35 -5.34 -5.33 -5.32 -5.31 -5.3  -5.29 -5.28 -5.27
#  -5.26 -5.25 -5.24 -5.23 -5.22 -5.21 -5.2  -5.19 -5.18 -5.17 -5.16 -5.15
#  -5.14 -5.13 -5.12 -5.11 -5.1  -5.09 -5.08 -5.07 -5.06 -5.05 -5.04 -5.03
#  -5.02 -5.01 -5.   -4.99 -4.98 -4.97 -4.96 -4.95 -4.94 -4.93 -4.92 -4.91
#  -4.9  -4.89 -4.88 -4.87 -4.86 -4.85 -4.84 -4.83 -4.82 -4.81 -4.8  -4.79
#  -4.78 -4.77 -4.76 -4.75 -4.74 -4.73 -4.72 -4.71 -4.7  -4.69 -4.68 -4.67
#  -4.66 -4.65 -4.64 -4.63 -4.62 -4.61 -4.6  -4.59 -4.58 -4.57 -4.56 -4.55
#  -4.54 -4.53 -4.52 -4.51 -4.5  -4.49 -4.48 -4.47 -4.46 -4.45 -4.44 -4.43
#  -4.42 -4.41 -4.4  -4.39 -4.38 -4.37 -4.36 -4.35 -4.34 -4.33 -4.32 -4.31
# ...

# %%
plot_cry_sigma_potential(sigma3)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx

# %%
plot_cry_sigma_carrier(sigma2)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yy, S_yz, S_zz
# sxx
