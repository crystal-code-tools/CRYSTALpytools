# %%
#ls

# %%
from file_readwrite import *
from plot import *

# %%
seebeck= Properties_output().read_cry_seebeck('./transport_zrnins_antisito_SEEBECK.DAT')

# %%
sigma= Properties_output().read_cry_sigma('./transport_zrnins_antisito_SIGMA.DAT')

# %%
plot_cry_zt(seebeck, sigma)
# Out:
# Please, choose the direction you want to plot.
# You can choose among ZT_xx, ZT_xy, ZT_xz, ZT_yx, ZT_yy, ZT_yz, ZT_zx, ZT_zy, ZT_zz
# ztxx
# Insert the k$_{tot}$ value in W$^{-1}$K$^{-1}$m10
# [array([0.00064239, 0.00354187, 0.00775326, ..., 0.06298761, 0.04046677,
#        0.02073936]), array([0.00028829, 0.00237532, 0.00591163, ..., 0.09870492, 0.08331267,
#        0.06782962]), array([1.41983301e-05, 8.72318440e-04, 3.60391967e-03, ...,
#        1.74755832e-01, 1.67308418e-01, 1.59759207e-01]), array([1.09794728e-03, 1.39606000e-05, 1.46590871e-03, ...,
#        3.14311780e-01, 3.15750626e-01, 3.18472946e-01]), array([4.40694526e-03, 6.48541655e-04, 1.83002129e-04, ...,
#        5.33058100e-01, 5.45455402e-01, 5.60773654e-01]), array([9.98333647e-03, 3.05546605e-03, 1.48970970e-04, ...,
#        8.34624350e-01, 8.60856086e-01, 8.91282133e-01]), array([0.01729545, 0.00702298, 0.00139496, ..., 1.21225799, 1.25531271,
#        1.30324913])]
