# %%
#ls

# %%
from file_readwrite import *
from plot import *

# %%
sigma = Properties_output().read_cry_seebeck('./boltz_final_newk60_SIGMA.DAT')

# %%
seebeck = Properties_output().read_cry_seebeck('./boltz_final_newk60_SEEBECK.DAT')

# %%
seebeck1= Properties_output().read_cry_seebeck('./transport_zrnins_inter_SEEBECK.DAT')

# %%
seebeck2= Properties_output().read_cry_seebeck('./transport_zrnins_antisito_SEEBECK.DAT')

# %%
seebeck3= Properties_output().read_cry_seebeck('./transport_zrnins_sb_SEEBECK.DAT')

# %%
plot_cry_multiseebeck(seebeck, seebeck1, seebeck2, seebeck3)
# Out:
# Insert the index of temperature you want to plot
# (i.e. if your temperature are [T1, T2, T3] indexes are [0, 1, 2])0
# Insert the lower value of chemical potential you want to plot in eV-3
# Inser the higher value of chemical potential you want to plot in eV-1
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
# sxx

# %%
plot_cry_seebeck_carrier(seebeck)
# Out:
# Please, choose the direction you want to plot.
# You can choose among S_xx, S_xy, S_xz, S_yx, S_yy, S_yz, S_yz, S_zx, S_zy, S_zz
# syy

# %%
plot_cry_zt(seebeck,sigma)
# Out:
# Please insert the value of ktot in W-1K-1m-16.5
# Please, choose the direction you want to plot.
# You can choose among ZT_xx, ZT_xy, ZT_xz, ZT_yx, ZT_yy, ZT_yz, ZT_yz, ZT_zx, ZT_zy, ZT_zz
# ztxx
